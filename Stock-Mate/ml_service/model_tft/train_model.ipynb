# %% [markdown]
# # TFT Model Training Notebook
#
# This notebook demonstrates the training of the Temporal Fusion Transformer model for stock price prediction.
#
# ## Overview
# - Data preparation and feature engineering
# - Model training with PyTorch Lightning
# - Model evaluation and prediction
# - Integration with StockMate microservices
